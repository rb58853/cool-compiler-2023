# %% [markdown]
# # Lexer

# %% [markdown]
# ##### Basic test case

# %%
from lexer.cool_lexer import CoolLexer
import os
case = "iis1.cl"


base_dir = os.getcwd()
base_url = os.path.join(base_dir[:-13], "tests/lexer/")

dir = '/'.join([base_url,case])
with open(dir, "r") as f:
    content = f.read()
    content = '<==> 98'
print("--------------------------CASE---------------------------")
print(content, end="\n\n")

print("-------------------------TOKENS--------------------------")
lexer = CoolLexer()
for token in lexer.tokenize(content):
    print(token)

print("\n-----------------------ERRORS--------------------------")
for e in lexer.errors:
    print(e)
# Out:
# --------------------------CASE---------------------------
# <==> 98
#
# -------------------------TOKENS--------------------------
# Token(type='LE', value='<=', lineno=1, index=0, end=2)
# Token(type='DARROW', value='=>', lineno=1, index=2, end=4)
# Token(type='INT_CONST', value=98, lineno=1, index=5, end=7)
#
# -----------------------ERRORS--------------------------

# %% [markdown]
# ##### Run all test cases

# %%
from lexer.cool_lexer import CoolLexer
import os

base_dir = os.getcwd()
base_url = os.path.join(base_dir[:-13], "tests/lexer/")
print (base_url)

cases = [case for case in os.listdir(base_url) if case.endswith('.cl')] 
for case in cases:
    dir = '/'.join([base_url,case])
    with open(dir, "r") as f:
        content = f.read()
    print("--------------------------CASE---------------------------")
    print(content, end="\n\n")

    print("-------------------------TOKENS--------------------------")
    lexer = CoolLexer()
    for token in lexer.tokenize(content):
        print(token)

    print("\n-----------------------ERRORS--------------------------")
    for e in lexer.errors:
        print(e)
    print("_____________________________________________________________________________________________________")
    print('\n\n')
# Out:
# /home/raul/Almacenamiento/Computation Sience/Compiler/cool-compiler-2023/tests/lexer/
# --------------------------CASE---------------------------
# (* Integers, Identifiers, and Special Notation *)
#
# 0007 123 +1 -1 +90 -09 +11113 -4r *a *self* c++
# 5! = 120, 2 + 2 = 5 or E = mc2; p + 1 @ p = 1:  for x in range(len(b))
# new / <- <<==> {( Int: Objet, Bool; String.string SELF_TYPE isvoid })
# class Class if then else fi testing Testing ~007agent_bond james_007B0N3SS___
# loop pool while tRuE or noT faLsE let in case of ESAC
#
# (*
# #3 INT_CONST 0007
# #3 INT_CONST 123
# #3 '+'
# #3 INT_CONST 1
# #3 '-'
# #3 INT_CONST 1
# #3 '+'
# #3 INT_CONST 90
# #3 '-'
# #3 INT_CONST 09
# #3 '+'
# #3 INT_CONST 11113
# #3 '-'
# #3 INT_CONST 4
# #3 OBJECTID r
# #3 '*'
# #3 OBJECTID a
# #3 '*'
# #3 OBJECTID self
# #3 '*'
# #3 OBJECTID c
# #3 '+'
# #3 '+'
# #4 INT_CONST 5
# #4 ERROR "!"
# #4 '='
# #4 INT_CONST 120
# #4 ','
# #4 INT_CONST 2
# #4 '+'
# #4 INT_CONST 2
# #4 '='
# #4 INT_CONST 5
# #4 OBJECTID or
# #4 TYPEID E
# #4 '='
# #4 OBJECTID mc2
# #4 ';'
# #4 OBJECTID p
# #4 '+'
# #4 INT_CONST 1
# #4 '@'
# #4 OBJECTID p
# #4 '='
# #4 INT_CONST 1
# #4 ':'
# #4 OBJECTID for
# #4 OBJECTID x
# #4 IN
# #4 OBJECTID range
# #4 '('
# #4 OBJECTID len
# #4 '('
# #4 OBJECTID b
# #4 ')'
# #4 ')'
# #5 NEW
# #5 '/'
# #5 ASSIGN
# #5 '<'
# #5 LE
# #5 DARROW
# #5 '{'
# #5 '('
# #5 TYPEID Int
# #5 ':'
# #5 TYPEID Objet
# #5 ','
# #5 TYPEID Bool
# #5 ';'
# #5 TYPEID String
# #5 '.'
# #5 OBJECTID string
# #5 TYPEID SELF_TYPE
# #5 ISVOID
# #5 '}'
# #5 ')'
# #6 CLASS
# #6 CLASS
# #6 IF
# #6 THEN
# #6 ELSE
# #6 FI
# #6 OBJECTID testing
# #6 TYPEID Testing
# #6 '~'
# #6 INT_CONST 007
# #6 OBJECTID agent_bond
# #6 OBJECTID james_007B0N3SS___
# #7 LOOP
# #7 POOL
# #7 WHILE
# #7 BOOL_CONST true
# #7 OBJECTID or
# #7 NOT
# #7 BOOL_CONST false
# #7 LET
# #7 IN
# #7 CASE
# #7 OF
# #7 ESAC
# *)
#
# -------------------------TOKENS--------------------------
# Token(type='INT_CONST', value=7, lineno=3, index=51, end=55)
# Token(type='INT_CONST', value=123, lineno=3, index=56, end=59)
# Token(type='+', value='+', lineno=3, index=60, end=61)
# Token(type='INT_CONST', value=1, lineno=3, index=61, end=62)
# Token(type='-', value='-', lineno=3, index=63, end=64)
# Token(type='INT_CONST', value=1, lineno=3, index=64, end=65)
# Token(type='+', value='+', lineno=3, index=66, end=67)
# Token(type='INT_CONST', value=90, lineno=3, index=67, end=69)
# Token(type='-', value='-', lineno=3, index=70, end=71)
# Token(type='INT_CONST', value=9, lineno=3, index=71, end=73)
# Token(type='+', value='+', lineno=3, index=74, end=75)
# Token(type='INT_CONST', value=11113, lineno=3, index=75, end=80)
# Token(type='-', value='-', lineno=3, index=81, end=82)
# Token(type='INT_CONST', value=4, lineno=3, index=82, end=83)
# Token(type='OBJECTID', value='r', lineno=3, index=83, end=84)
# Token(type='*', value='*', lineno=3, index=85, end=86)
# Token(type='OBJECTID', value='a', lineno=3, index=86, end=87)
# Token(type='*', value='*', lineno=3, index=88, end=89)
# Token(type='OBJECTID', value='self', lineno=3, index=89, end=93)
# Token(type='*', value='*', lineno=3, index=93, end=94)
# Token(type='OBJECTID', value='c', lineno=3, index=95, end=96)
# Token(type='+', value='+', lineno=3, index=96, end=97)
# Token(type='+', value='+', lineno=3, index=97, end=98)
# Token(type='INT_CONST', value=5, lineno=4, index=100, end=101)
# ERROR(LexicographicError(4,2): Invalid Character='!')
# Token(type='=', value='=', lineno=4, index=103, end=104)
# Token(type='INT_CONST', value=120, lineno=4, index=105, end=108)
# Token(type=',', value=',', lineno=4, index=108, end=109)
# Token(type='INT_CONST', value=2, lineno=4, index=110, end=111)
# Token(type='+', value='+', lineno=4, index=112, end=113)
# Token(type='INT_CONST', value=2, lineno=4, index=114, end=115)
# Token(type='=', value='=', lineno=4, index=116, end=117)
# Token(type='INT_CONST', value=5, lineno=4, index=118, end=119)
# Token(type='OBJECTID', value='or', lineno=4, index=120, end=122)
# Token(type='TYPEID', value='E', lineno=4, index=123, end=124)
# Token(type='=', value='=', lineno=4, index=125, end=126)
# Token(type='OBJECTID', value='mc2', lineno=4, index=127, end=130)
# Token(type=';', value=';', lineno=4, index=130, end=131)
# Token(type='OBJECTID', value='p', lineno=4, index=132, end=133)
# Token(type='+', value='+', lineno=4, index=134, end=135)
# Token(type='INT_CONST', value=1, lineno=4, index=136, end=137)
# Token(type='@', value='@', lineno=4, index=138, end=139)
# Token(type='OBJECTID', value='p', lineno=4, index=140, end=141)
# Token(type='=', value='=', lineno=4, index=142, end=143)
# Token(type='INT_CONST', value=1, lineno=4, index=144, end=145)
# Token(type=':', value=':', lineno=4, index=145, end=146)
# Token(type='OBJECTID', value='for', lineno=4, index=148, end=151)
# Token(type='OBJECTID', value='x', lineno=4, index=152, end=153)
# Token(type='IN', value='in', lineno=4, index=154, end=156)
# Token(type='OBJECTID', value='range', lineno=4, index=157, end=162)
# Token(type='(', value='(', lineno=4, index=162, end=163)
# Token(type='OBJECTID', value='len', lineno=4, index=163, end=166)
# Token(type='(', value='(', lineno=4, index=166, end=167)
# Token(type='OBJECTID', value='b', lineno=4, index=167, end=168)
# Token(type=')', value=')', lineno=4, index=168, end=169)
# Token(type=')', value=')', lineno=4, index=169, end=170)
# Token(type='NEW', value='new', lineno=5, index=171, end=174)
# Token(type='/', value='/', lineno=5, index=175, end=176)
# Token(type='ASSIGN', value='<-', lineno=5, index=177, end=179)
# Token(type='<', value='<', lineno=5, index=180, end=181)
# Token(type='LE', value='<=', lineno=5, index=181, end=183)
# Token(type='DARROW', value='=>', lineno=5, index=183, end=185)
# Token(type='{', value='{', lineno=5, index=186, end=187)
# Token(type='(', value='(', lineno=5, index=187, end=188)
# Token(type='TYPEID', value='Int', lineno=5, index=189, end=192)
# Token(type=':', value=':', lineno=5, index=192, end=193)
# Token(type='TYPEID', value='Objet', lineno=5, index=194, end=199)
# Token(type=',', value=',', lineno=5, index=199, end=200)
# Token(type='TYPEID', value='Bool', lineno=5, index=201, end=205)
# Token(type=';', value=';', lineno=5, index=205, end=206)
# Token(type='TYPEID', value='String', lineno=5, index=207, end=213)
# Token(type='.', value='.', lineno=5, index=213, end=214)
# Token(type='OBJECTID', value='string', lineno=5, index=214, end=220)
# Token(type='TYPEID', value='SELF_TYPE', lineno=5, index=221, end=230)
# Token(type='ISVOID', value='isvoid', lineno=5, index=231, end=237)
# Token(type='}', value='}', lineno=5, index=238, end=239)
# Token(type=')', value=')', lineno=5, index=239, end=240)
# Token(type='CLASS', value='class', lineno=6, index=241, end=246)
# Token(type='CLASS', value='Class', lineno=6, index=247, end=252)
# Token(type='IF', value='if', lineno=6, index=253, end=255)
# Token(type='THEN', value='then', lineno=6, index=256, end=260)
# Token(type='ELSE', value='else', lineno=6, index=261, end=265)
# Token(type='FI', value='fi', lineno=6, index=266, end=268)
# Token(type='OBJECTID', value='testing', lineno=6, index=269, end=276)
# Token(type='TYPEID', value='Testing', lineno=6, index=277, end=284)
# Token(type='~', value='~', lineno=6, index=285, end=286)
# Token(type='INT_CONST', value=7, lineno=6, index=286, end=289)
# Token(type='OBJECTID', value='agent_bond', lineno=6, index=289, end=299)
# Token(type='OBJECTID', value='james_007B0N3SS___', lineno=6, index=300, end=318)
# Token(type='LOOP', value='loop', lineno=7, index=319, end=323)
# Token(type='POOL', value='pool', lineno=7, index=324, end=328)
# Token(type='WHILE', value='while', lineno=7, index=329, end=334)
# Token(type='TRUE', value='tRuE', lineno=7, index=335, end=339)
# Token(type='OBJECTID', value='or', lineno=7, index=340, end=342)
# Token(type='NOT', value='noT', lineno=7, index=343, end=346)
# Token(type='FALSE', value='faLsE', lineno=7, index=347, end=352)
# Token(type='LET', value='let', lineno=7, index=353, end=356)
# Token(type='IN', value='in', lineno=7, index=357, end=359)
# Token(type='CASE', value='case', lineno=7, index=360, end=364)
# Token(type='OF', value='of', lineno=7, index=365, end=367)
# Token(type='ESAC', value='ESAC', lineno=7, index=368, end=372)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(4,2): Invalid Character='!')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# (* Integers, Identifiers, and Special Notation *)
#
# factorial(5) = 120, 2 + 2 = 5 or E = mc2; p + 1 resto p = 1: {@.@ for x in range(len(b))}
#
# new / <- <<==> {( Int: Objet, Bool; String.string SELF_TYPE isvoid })
#
#
# class Class if then else fi testing Testing ~007agent_bond _james_007bones___
#
#
#
# 0007 123 +1 -1 +90 -09 +11113 -4r *a *self* c++
# loop pool while tRuE or noT faLsE let in case of ESAC
#
# (*
# #3 OBJECTID factorial
# #3 '('
# #3 INT_CONST 5
# #3 ')'
# #3 '='
# #3 INT_CONST 120
# #3 ','
# #3 INT_CONST 2
# #3 '+'
# #3 INT_CONST 2
# #3 '='
# #3 INT_CONST 5
# #3 OBJECTID or
# #3 TYPEID E
# #3 '='
# #3 OBJECTID mc2
# #3 ';'
# #3 OBJECTID p
# #3 '+'
# #3 INT_CONST 1
# #3 OBJECTID resto
# #3 OBJECTID p
# #3 '='
# #3 INT_CONST 1
# #3 ':'
# #3 '{'
# #3 '@'
# #3 '.'
# #3 '@'
# #3 OBJECTID for
# #3 OBJECTID x
# #3 IN
# #3 OBJECTID range
# #3 '('
# #3 OBJECTID len
# #3 '('
# #3 OBJECTID b
# #3 ')'
# #3 ')'
# #3 '}'
# #5 NEW
# #5 '/'
# #5 ASSIGN
# #5 '<'
# #5 LE
# #5 DARROW
# #5 '{'
# #5 '('
# #5 TYPEID Int
# #5 ':'
# #5 TYPEID Objet
# #5 ','
# #5 TYPEID Bool
# #5 ';'
# #5 TYPEID String
# #5 '.'
# #5 OBJECTID string
# #5 TYPEID SELF_TYPE
# #5 ISVOID
# #5 '}'
# #5 ')'
# #8 CLASS
# #8 CLASS
# #8 IF
# #8 THEN
# #8 ELSE
# #8 FI
# #8 OBJECTID testing
# #8 TYPEID Testing
# #8 '~'
# #8 INT_CONST 007
# #8 OBJECTID agent_bond
# #8 ERROR "_"
# #8 OBJECTID james_007bones___
# #12 INT_CONST 0007
# #12 INT_CONST 123
# #12 '+'
# #12 INT_CONST 1
# #12 '-'
# #12 INT_CONST 1
# #12 '+'
# #12 INT_CONST 90
# #12 '-'
# #12 INT_CONST 09
# #12 '+'
# #12 INT_CONST 11113
# #12 '-'
# #12 INT_CONST 4
# #12 OBJECTID r
# #12 '*'
# #12 OBJECTID a
# #12 '*'
# #12 OBJECTID self
# #12 '*'
# #12 OBJECTID c
# #12 '+'
# #12 '+'
# #13 LOOP
# #13 POOL
# #13 WHILE
# #13 BOOL_CONST true
# #13 OBJECTID or
# #13 NOT
# #13 BOOL_CONST false
# #13 LET
# #13 IN
# #13 CASE
# #13 OF
# #13 ESAC
# *)
#
# -------------------------TOKENS--------------------------
# Token(type='OBJECTID', value='factorial', lineno=3, index=51, end=60)
# Token(type='(', value='(', lineno=3, index=60, end=61)
# Token(type='INT_CONST', value=5, lineno=3, index=61, end=62)
# Token(type=')', value=')', lineno=3, index=62, end=63)
# Token(type='=', value='=', lineno=3, index=64, end=65)
# Token(type='INT_CONST', value=120, lineno=3, index=66, end=69)
# Token(type=',', value=',', lineno=3, index=69, end=70)
# Token(type='INT_CONST', value=2, lineno=3, index=71, end=72)
# Token(type='+', value='+', lineno=3, index=73, end=74)
# Token(type='INT_CONST', value=2, lineno=3, index=75, end=76)
# Token(type='=', value='=', lineno=3, index=77, end=78)
# Token(type='INT_CONST', value=5, lineno=3, index=79, end=80)
# Token(type='OBJECTID', value='or', lineno=3, index=81, end=83)
# Token(type='TYPEID', value='E', lineno=3, index=84, end=85)
# Token(type='=', value='=', lineno=3, index=86, end=87)
# Token(type='OBJECTID', value='mc2', lineno=3, index=88, end=91)
# Token(type=';', value=';', lineno=3, index=91, end=92)
# Token(type='OBJECTID', value='p', lineno=3, index=93, end=94)
# Token(type='+', value='+', lineno=3, index=95, end=96)
# Token(type='INT_CONST', value=1, lineno=3, index=97, end=98)
# Token(type='OBJECTID', value='resto', lineno=3, index=99, end=104)
# Token(type='OBJECTID', value='p', lineno=3, index=105, end=106)
# Token(type='=', value='=', lineno=3, index=107, end=108)
# Token(type='INT_CONST', value=1, lineno=3, index=109, end=110)
# Token(type=':', value=':', lineno=3, index=110, end=111)
# Token(type='{', value='{', lineno=3, index=112, end=113)
# Token(type='@', value='@', lineno=3, index=113, end=114)
# Token(type='.', value='.', lineno=3, index=114, end=115)
# Token(type='@', value='@', lineno=3, index=115, end=116)
# Token(type='OBJECTID', value='for', lineno=3, index=117, end=120)
# Token(type='OBJECTID', value='x', lineno=3, index=121, end=122)
# Token(type='IN', value='in', lineno=3, index=123, end=125)
# Token(type='OBJECTID', value='range', lineno=3, index=126, end=131)
# Token(type='(', value='(', lineno=3, index=131, end=132)
# Token(type='OBJECTID', value='len', lineno=3, index=132, end=135)
# Token(type='(', value='(', lineno=3, index=135, end=136)
# Token(type='OBJECTID', value='b', lineno=3, index=136, end=137)
# Token(type=')', value=')', lineno=3, index=137, end=138)
# Token(type=')', value=')', lineno=3, index=138, end=139)
# Token(type='}', value='}', lineno=3, index=139, end=140)
# Token(type='NEW', value='new', lineno=5, index=142, end=145)
# Token(type='/', value='/', lineno=5, index=146, end=147)
# Token(type='ASSIGN', value='<-', lineno=5, index=148, end=150)
# Token(type='<', value='<', lineno=5, index=151, end=152)
# Token(type='LE', value='<=', lineno=5, index=152, end=154)
# Token(type='DARROW', value='=>', lineno=5, index=154, end=156)
# Token(type='{', value='{', lineno=5, index=157, end=158)
# Token(type='(', value='(', lineno=5, index=158, end=159)
# Token(type='TYPEID', value='Int', lineno=5, index=160, end=163)
# Token(type=':', value=':', lineno=5, index=163, end=164)
# Token(type='TYPEID', value='Objet', lineno=5, index=165, end=170)
# Token(type=',', value=',', lineno=5, index=170, end=171)
# Token(type='TYPEID', value='Bool', lineno=5, index=172, end=176)
# Token(type=';', value=';', lineno=5, index=176, end=177)
# Token(type='TYPEID', value='String', lineno=5, index=178, end=184)
# Token(type='.', value='.', lineno=5, index=184, end=185)
# Token(type='OBJECTID', value='string', lineno=5, index=185, end=191)
# Token(type='TYPEID', value='SELF_TYPE', lineno=5, index=192, end=201)
# Token(type='ISVOID', value='isvoid', lineno=5, index=202, end=208)
# Token(type='}', value='}', lineno=5, index=209, end=210)
# Token(type=')', value=')', lineno=5, index=210, end=211)
# Token(type='CLASS', value='class', lineno=8, index=214, end=219)
# Token(type='CLASS', value='Class', lineno=8, index=220, end=225)
# Token(type='IF', value='if', lineno=8, index=226, end=228)
# Token(type='THEN', value='then', lineno=8, index=229, end=233)
# Token(type='ELSE', value='else', lineno=8, index=234, end=238)
# Token(type='FI', value='fi', lineno=8, index=239, end=241)
# Token(type='OBJECTID', value='testing', lineno=8, index=242, end=249)
# Token(type='TYPEID', value='Testing', lineno=8, index=250, end=257)
# Token(type='~', value='~', lineno=8, index=258, end=259)
# Token(type='INT_CONST', value=7, lineno=8, index=259, end=262)
# Token(type='OBJECTID', value='agent_bond', lineno=8, index=262, end=272)
# ERROR(LexicographicError(8,60): Invalid Character='_')
# Token(type='OBJECTID', value='james_007bones___', lineno=8, index=274, end=291)
# Token(type='INT_CONST', value=7, lineno=12, index=295, end=299)
# Token(type='INT_CONST', value=123, lineno=12, index=300, end=303)
# Token(type='+', value='+', lineno=12, index=304, end=305)
# Token(type='INT_CONST', value=1, lineno=12, index=305, end=306)
# Token(type='-', value='-', lineno=12, index=307, end=308)
# Token(type='INT_CONST', value=1, lineno=12, index=308, end=309)
# Token(type='+', value='+', lineno=12, index=310, end=311)
# Token(type='INT_CONST', value=90, lineno=12, index=311, end=313)
# Token(type='-', value='-', lineno=12, index=314, end=315)
# Token(type='INT_CONST', value=9, lineno=12, index=315, end=317)
# Token(type='+', value='+', lineno=12, index=318, end=319)
# Token(type='INT_CONST', value=11113, lineno=12, index=319, end=324)
# Token(type='-', value='-', lineno=12, index=325, end=326)
# Token(type='INT_CONST', value=4, lineno=12, index=326, end=327)
# Token(type='OBJECTID', value='r', lineno=12, index=327, end=328)
# Token(type='*', value='*', lineno=12, index=329, end=330)
# Token(type='OBJECTID', value='a', lineno=12, index=330, end=331)
# Token(type='*', value='*', lineno=12, index=332, end=333)
# Token(type='OBJECTID', value='self', lineno=12, index=333, end=337)
# Token(type='*', value='*', lineno=12, index=337, end=338)
# Token(type='OBJECTID', value='c', lineno=12, index=339, end=340)
# Token(type='+', value='+', lineno=12, index=340, end=341)
# Token(type='+', value='+', lineno=12, index=341, end=342)
# Token(type='LOOP', value='loop', lineno=13, index=344, end=348)
# Token(type='POOL', value='pool', lineno=13, index=349, end=353)
# Token(type='WHILE', value='while', lineno=13, index=354, end=359)
# Token(type='TRUE', value='tRuE', lineno=13, index=360, end=364)
# Token(type='OBJECTID', value='or', lineno=13, index=365, end=367)
# Token(type='NOT', value='noT', lineno=13, index=368, end=371)
# Token(type='FALSE', value='faLsE', lineno=13, index=372, end=377)
# Token(type='LET', value='let', lineno=13, index=378, end=381)
# Token(type='IN', value='in', lineno=13, index=382, end=384)
# Token(type='CASE', value='case', lineno=13, index=385, end=389)
# Token(type='OF', value='of', lineno=13, index=390, end=392)
# Token(type='ESAC', value='ESAC', lineno=13, index=393, end=397)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(8,60): Invalid Character='_')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# (* Integers, Identifiers, and Special Notation *)
#
#
# loop pool while tRuE or noT faLsE let in case of ESAC
# new / <- <<==> {( Int: Objet, Bool; String.string SELF_TYPE isvoid })
# class Class if then else fi testing Testing ~007agent_bond james_007bones___
#
# factorial(5) = 120, 2 + 2 = 5 or E = mc2; p + 1 resto p = 1: [@.@ for x in range(len(b))]
#
# 0007 123 +1 -1 +90 -09 +11113 -4r *a *self* c++
#
# (*
# #4 LOOP
# #4 POOL
# #4 WHILE
# #4 BOOL_CONST true
# #4 OBJECTID or
# #4 NOT
# #4 BOOL_CONST false
# #4 LET
# #4 IN
# #4 CASE
# #4 OF
# #4 ESAC
# #5 NEW
# #5 '/'
# #5 ASSIGN
# #5 '<'
# #5 LE
# #5 DARROW
# #5 '{'
# #5 '('
# #5 TYPEID Int
# #5 ':'
# #5 TYPEID Objet
# #5 ','
# #5 TYPEID Bool
# #5 ';'
# #5 TYPEID String
# #5 '.'
# #5 OBJECTID string
# #5 TYPEID SELF_TYPE
# #5 ISVOID
# #5 '}'
# #5 ')'
# #6 CLASS
# #6 CLASS
# #6 IF
# #6 THEN
# #6 ELSE
# #6 FI
# #6 OBJECTID testing
# #6 TYPEID Testing
# #6 '~'
# #6 INT_CONST 007
# #6 OBJECTID agent_bond
# #6 OBJECTID james_007bones___
# #8 OBJECTID factorial
# #8 '('
# #8 INT_CONST 5
# #8 ')'
# #8 '='
# #8 INT_CONST 120
# #8 ','
# #8 INT_CONST 2
# #8 '+'
# #8 INT_CONST 2
# #8 '='
# #8 INT_CONST 5
# #8 OBJECTID or
# #8 TYPEID E
# #8 '='
# #8 OBJECTID mc2
# #8 ';'
# #8 OBJECTID p
# #8 '+'
# #8 INT_CONST 1
# #8 OBJECTID resto
# #8 OBJECTID p
# #8 '='
# #8 INT_CONST 1
# #8 ':'
# #8 ERROR "["
# #8 '@'
# #8 '.'
# #8 '@'
# #8 OBJECTID for
# #8 OBJECTID x
# #8 IN
# #8 OBJECTID range
# #8 '('
# #8 OBJECTID len
# #8 '('
# #8 OBJECTID b
# #8 ')'
# #8 ')'
# #8 ERROR "]"
# #10 INT_CONST 0007
# #10 INT_CONST 123
# #10 '+'
# #10 INT_CONST 1
# #10 '-'
# #10 INT_CONST 1
# #10 '+'
# #10 INT_CONST 90
# #10 '-'
# #10 INT_CONST 09
# #10 '+'
# #10 INT_CONST 11113
# #10 '-'
# #10 INT_CONST 4
# #10 OBJECTID r
# #10 '*'
# #10 OBJECTID a
# #10 '*'
# #10 OBJECTID self
# #10 '*'
# #10 OBJECTID c
# #10 '+'
# #10 '+'
# *)
#
#
# -------------------------TOKENS--------------------------
# Token(type='LOOP', value='loop', lineno=4, index=52, end=56)
# Token(type='POOL', value='pool', lineno=4, index=57, end=61)
# Token(type='WHILE', value='while', lineno=4, index=62, end=67)
# Token(type='TRUE', value='tRuE', lineno=4, index=68, end=72)
# Token(type='OBJECTID', value='or', lineno=4, index=73, end=75)
# Token(type='NOT', value='noT', lineno=4, index=76, end=79)
# Token(type='FALSE', value='faLsE', lineno=4, index=80, end=85)
# Token(type='LET', value='let', lineno=4, index=86, end=89)
# Token(type='IN', value='in', lineno=4, index=90, end=92)
# Token(type='CASE', value='case', lineno=4, index=93, end=97)
# Token(type='OF', value='of', lineno=4, index=98, end=100)
# Token(type='ESAC', value='ESAC', lineno=4, index=101, end=105)
# Token(type='NEW', value='new', lineno=5, index=106, end=109)
# Token(type='/', value='/', lineno=5, index=110, end=111)
# Token(type='ASSIGN', value='<-', lineno=5, index=112, end=114)
# Token(type='<', value='<', lineno=5, index=115, end=116)
# Token(type='LE', value='<=', lineno=5, index=116, end=118)
# Token(type='DARROW', value='=>', lineno=5, index=118, end=120)
# Token(type='{', value='{', lineno=5, index=121, end=122)
# Token(type='(', value='(', lineno=5, index=122, end=123)
# Token(type='TYPEID', value='Int', lineno=5, index=124, end=127)
# Token(type=':', value=':', lineno=5, index=127, end=128)
# Token(type='TYPEID', value='Objet', lineno=5, index=129, end=134)
# Token(type=',', value=',', lineno=5, index=134, end=135)
# Token(type='TYPEID', value='Bool', lineno=5, index=136, end=140)
# Token(type=';', value=';', lineno=5, index=140, end=141)
# Token(type='TYPEID', value='String', lineno=5, index=142, end=148)
# Token(type='.', value='.', lineno=5, index=148, end=149)
# Token(type='OBJECTID', value='string', lineno=5, index=149, end=155)
# Token(type='TYPEID', value='SELF_TYPE', lineno=5, index=156, end=165)
# Token(type='ISVOID', value='isvoid', lineno=5, index=166, end=172)
# Token(type='}', value='}', lineno=5, index=173, end=174)
# Token(type=')', value=')', lineno=5, index=174, end=175)
# Token(type='CLASS', value='class', lineno=6, index=176, end=181)
# Token(type='CLASS', value='Class', lineno=6, index=182, end=187)
# Token(type='IF', value='if', lineno=6, index=188, end=190)
# Token(type='THEN', value='then', lineno=6, index=191, end=195)
# Token(type='ELSE', value='else', lineno=6, index=196, end=200)
# Token(type='FI', value='fi', lineno=6, index=201, end=203)
# Token(type='OBJECTID', value='testing', lineno=6, index=204, end=211)
# Token(type='TYPEID', value='Testing', lineno=6, index=212, end=219)
# Token(type='~', value='~', lineno=6, index=220, end=221)
# Token(type='INT_CONST', value=7, lineno=6, index=221, end=224)
# Token(type='OBJECTID', value='agent_bond', lineno=6, index=224, end=234)
# Token(type='OBJECTID', value='james_007bones___', lineno=6, index=235, end=252)
# Token(type='OBJECTID', value='factorial', lineno=8, index=254, end=263)
# Token(type='(', value='(', lineno=8, index=263, end=264)
# Token(type='INT_CONST', value=5, lineno=8, index=264, end=265)
# Token(type=')', value=')', lineno=8, index=265, end=266)
# Token(type='=', value='=', lineno=8, index=267, end=268)
# Token(type='INT_CONST', value=120, lineno=8, index=269, end=272)
# Token(type=',', value=',', lineno=8, index=272, end=273)
# Token(type='INT_CONST', value=2, lineno=8, index=274, end=275)
# Token(type='+', value='+', lineno=8, index=276, end=277)
# Token(type='INT_CONST', value=2, lineno=8, index=278, end=279)
# Token(type='=', value='=', lineno=8, index=280, end=281)
# Token(type='INT_CONST', value=5, lineno=8, index=282, end=283)
# Token(type='OBJECTID', value='or', lineno=8, index=284, end=286)
# Token(type='TYPEID', value='E', lineno=8, index=287, end=288)
# Token(type='=', value='=', lineno=8, index=289, end=290)
# Token(type='OBJECTID', value='mc2', lineno=8, index=291, end=294)
# Token(type=';', value=';', lineno=8, index=294, end=295)
# Token(type='OBJECTID', value='p', lineno=8, index=296, end=297)
# Token(type='+', value='+', lineno=8, index=298, end=299)
# Token(type='INT_CONST', value=1, lineno=8, index=300, end=301)
# Token(type='OBJECTID', value='resto', lineno=8, index=302, end=307)
# Token(type='OBJECTID', value='p', lineno=8, index=308, end=309)
# Token(type='=', value='=', lineno=8, index=310, end=311)
# Token(type='INT_CONST', value=1, lineno=8, index=312, end=313)
# Token(type=':', value=':', lineno=8, index=313, end=314)
# ERROR(LexicographicError(8,62): Invalid Character='[')
# Token(type='@', value='@', lineno=8, index=316, end=317)
# Token(type='.', value='.', lineno=8, index=317, end=318)
# Token(type='@', value='@', lineno=8, index=318, end=319)
# Token(type='OBJECTID', value='for', lineno=8, index=320, end=323)
# Token(type='OBJECTID', value='x', lineno=8, index=324, end=325)
# Token(type='IN', value='in', lineno=8, index=326, end=328)
# Token(type='OBJECTID', value='range', lineno=8, index=329, end=334)
# Token(type='(', value='(', lineno=8, index=334, end=335)
# Token(type='OBJECTID', value='len', lineno=8, index=335, end=338)
# Token(type='(', value='(', lineno=8, index=338, end=339)
# Token(type='OBJECTID', value='b', lineno=8, index=339, end=340)
# Token(type=')', value=')', lineno=8, index=340, end=341)
# Token(type=')', value=')', lineno=8, index=341, end=342)
# ERROR(LexicographicError(8,89): Invalid Character=']')
# Token(type='INT_CONST', value=7, lineno=10, index=345, end=349)
# Token(type='INT_CONST', value=123, lineno=10, index=350, end=353)
# Token(type='+', value='+', lineno=10, index=354, end=355)
# Token(type='INT_CONST', value=1, lineno=10, index=355, end=356)
# Token(type='-', value='-', lineno=10, index=357, end=358)
# Token(type='INT_CONST', value=1, lineno=10, index=358, end=359)
# Token(type='+', value='+', lineno=10, index=360, end=361)
# Token(type='INT_CONST', value=90, lineno=10, index=361, end=363)
# Token(type='-', value='-', lineno=10, index=364, end=365)
# Token(type='INT_CONST', value=9, lineno=10, index=365, end=367)
# Token(type='+', value='+', lineno=10, index=368, end=369)
# Token(type='INT_CONST', value=11113, lineno=10, index=369, end=374)
# Token(type='-', value='-', lineno=10, index=375, end=376)
# Token(type='INT_CONST', value=4, lineno=10, index=376, end=377)
# Token(type='OBJECTID', value='r', lineno=10, index=377, end=378)
# Token(type='*', value='*', lineno=10, index=379, end=380)
# Token(type='OBJECTID', value='a', lineno=10, index=380, end=381)
# Token(type='*', value='*', lineno=10, index=382, end=383)
# Token(type='OBJECTID', value='self', lineno=10, index=383, end=387)
# Token(type='*', value='*', lineno=10, index=387, end=388)
# Token(type='OBJECTID', value='c', lineno=10, index=389, end=390)
# Token(type='+', value='+', lineno=10, index=390, end=391)
# Token(type='+', value='+', lineno=10, index=391, end=392)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(8,62): Invalid Character='[')
# ERROR(LexicographicError(8,89): Invalid Character=']')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# --Any characters between two dashes “--” and the next newline
# --(or EOF, if there is no next newline) are treated as comments
#
# (*(*(*
# Comments may also be written by enclosing
# text in (∗ . . . ∗). The latter form of comment may be nested.
# Comments cannot cross file boundaries.
# *)*)*)
#
# class Error() {
#
#         (* There was once a comment,
#          that was quite long.
#          But, the reader soon discovered that
#          the comment was indeed longer than
#          previously assumed. Now, the reader
#          was in a real dilemma; is the comment
#          ever gonna end? If I stop reading, will
#          it end?
#          He started imagining all sorts of things.
#          He thought about heisenberg's cat and how
#          how that relates to the end of the sentence.
#          He thought to himself "I'm gonna stop reading".
#          "If I keep reading this comment, I'm gonna know
#          the fate of this sentence; That will be disastorous."
#          He knew that such a comment was gonna extend to
#          another file. It was too awesome to be contained in
#          a single file. And he would have kept reading too...
#          if only...
#          cool wasn't a super-duper-fab-awesomest language;
#          but cool is that language;
#          "This comment shall go not cross this file" said cool.
#          Alas! The reader could read no more.
#          There was once a comment,
#          that was quite long.
#          But, the reader soon discovered that
#          the comment was indeed longer than
#          previously assumed. Now, the reader
#          was in a real dilemma; is the comment
#          ever gonna end? If I stop reading, will
#          it end?
#          He started imagining all sorts of things.
#          He thought about heisenberg's cat and how
#          how that relates to the end of the sentence.
#          He thought to himself "I'm gonna stop reading".
#          "If I keep reading this comment, I'm gonna know
#          the fate of this sentence; That will be disastorous."
#          He knew that such a comment was gonna extend to
#          another file. It was too awesome to be contained in
#          a single file. And he would have kept reading too...
#          if only...
#          cool wasn't a super-duper-fab-awesomest language;
#          but cool is that language;
#          "This comment shall go not cross this file" said cool.
#          Alas! The reader could read no more.
#
# -------------------------TOKENS--------------------------
# Token(type='*', value='*', lineno=4, index=280, end=281)
# Token(type=')', value=')', lineno=4, index=281, end=282)
# Token(type='*', value='*', lineno=4, index=282, end=283)
# Token(type=')', value=')', lineno=4, index=283, end=284)
# Token(type='CLASS', value='class', lineno=6, index=286, end=291)
# Token(type='TYPEID', value='Error', lineno=6, index=292, end=297)
# Token(type='(', value='(', lineno=6, index=297, end=298)
# Token(type=')', value=')', lineno=6, index=298, end=299)
# Token(type='{', value='{', lineno=6, index=300, end=301)
# ERROR(LexicographicError(8,2104): comment error='...d no more.')
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(8,2104): comment error='...d no more.')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# "kjas\"lnnsdj\nfljrdsaf"
# @.$.@
# @*%*@
# "alkjfldajf""dasfadsf
#
# (*
# #1 STR_CONST "kjas\"lnnsdj\nfljrdsaf"
# #2 '@'
# #2 '.'
# #2 ERROR "$"
# #2 '.'
# #2 '@'
# #3 '@'
# #3 '*'
# #3 ERROR "%"
# #3 '*'
# #3 '@'
# #4 STR_CONST "alkjfldajf"
# #4 ERROR "Unterminated string constant"
# *)
#
# -------------------------TOKENS--------------------------
# TOKEN(type='STRING', value = '"kjas"lnnsdj\nfljrdsaf"', lineno = 1, index = 0, end = 25)
# Token(type='@', value='@', lineno=2, index=25, end=26)
# Token(type='.', value='.', lineno=2, index=26, end=27)
# ERROR(LexicographicError(2,3): Invalid Character='$')
# Token(type='.', value='.', lineno=2, index=28, end=29)
# Token(type='@', value='@', lineno=2, index=29, end=30)
# Token(type='@', value='@', lineno=3, index=31, end=32)
# Token(type='*', value='*', lineno=3, index=32, end=33)
# ERROR(LexicographicError(3,3): Invalid Character='%')
# Token(type='*', value='*', lineno=3, index=34, end=35)
# Token(type='@', value='@', lineno=3, index=35, end=36)
# TOKEN(type='STRING', value = '"alkjfldajf"', lineno = 4, index = 37, end = 50)
# ERROR(LexicographicError(4,22): Unterminated string constant='"dasfadsf')
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(2,3): Invalid Character='$')
# ERROR(LexicographicError(3,3): Invalid Character='%')
# ERROR(LexicographicError(4,22): Unterminated string constant='"dasfadsf')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# "lkjdsafkljdsalfj\u0000dsafdsaf\u0000djafslkjdsalf\nsdajf\" lkjfdsasdkjfl"123
# adsfasklj#
# LKldsajf iNhERITS
# "lkdsajf"
#
# (*
# #1 STR_CONST "lkjdsafkljdsalfju0000dsafdsafu0000djafslkjdsalf\nsdajf\" lkjfdsasdkjfl"
# #1 INT_CONST 123
# #2 OBJECTID adsfasklj
# #2 ERROR "#"
# #3 TYPEID LKldsajf
# #3 INHERITS
# #4 STR_CONST "lkdsajf"
# *)
#
# -------------------------TOKENS--------------------------
# TOKEN(type='STRING', value = '"lkjdsafkljdsalfju0000dsafdsafu0000djafslkjdsalf\nsdajf" lkjfdsasdkjfl"', lineno = 1, index = 0, end = 75)
# Token(type='INT_CONST', value=123, lineno=1, index=74, end=77)
# Token(type='OBJECTID', value='adsfasklj', lineno=2, index=78, end=87)
# ERROR(LexicographicError(2,10): Invalid Character='#')
# Token(type='TYPEID', value='LKldsajf', lineno=3, index=89, end=97)
# Token(type='INHERITS', value='iNhERITS', lineno=3, index=98, end=106)
# TOKEN(type='STRING', value = '"lkdsajf"', lineno = 4, index = 107, end = 117)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(2,10): Invalid Character='#')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# (* Integers, Identifiers, and Special Notation *)
#
# factorial(5) = 120, 2 + 2 = 5 or E = mc^2; p + 1 @ p = 1: z for x in range(len(b)))
#
# loop pool while tRuE or noT faLsE let in case of ESAC
#
# new / <- <<==> {( Int: Objet, Bool; String.string SELF_TYPE isvoid })
#
#
# 0007 123 +1 -1 +90 -09 +11113 -4r *a *self* c++
# class Class if then else fi testing Testing ~007agent_bond james_007bones___
#
# (*
# #3 OBJECTID factorial
# #3 '('
# #3 INT_CONST 5
# #3 ')'
# #3 '='
# #3 INT_CONST 120
# #3 ','
# #3 INT_CONST 2
# #3 '+'
# #3 INT_CONST 2
# #3 '='
# #3 INT_CONST 5
# #3 OBJECTID or
# #3 TYPEID E
# #3 '='
# #3 OBJECTID mc
# #3 ERROR "^"
# #3 INT_CONST 2
# #3 ';'
# #3 OBJECTID p
# #3 '+'
# #3 INT_CONST 1
# #3 '@'
# #3 OBJECTID p
# #3 '='
# #3 INT_CONST 1
# #3 ':'
# #3 OBJECTID z
# #3 OBJECTID for
# #3 OBJECTID x
# #3 IN
# #3 OBJECTID range
# #3 '('
# #3 OBJECTID len
# #3 '('
# #3 OBJECTID b
# #3 ')'
# #3 ')'
# #3 ')'
# #5 LOOP
# #5 POOL
# #5 WHILE
# #5 BOOL_CONST true
# #5 OBJECTID or
# #5 NOT
# #5 BOOL_CONST false
# #5 LET
# #5 IN
# #5 CASE
# #5 OF
# #5 ESAC
# #7 NEW
# #7 '/'
# #7 ASSIGN
# #7 '<'
# #7 LE
# #7 DARROW
# #7 '{'
# #7 '('
# #7 TYPEID Int
# #7 ':'
# #7 TYPEID Objet
# #7 ','
# #7 TYPEID Bool
# #7 ';'
# #7 TYPEID String
# #7 '.'
# #7 OBJECTID string
# #7 TYPEID SELF_TYPE
# #7 ISVOID
# #7 '}'
# #7 ')'
# #10 INT_CONST 0007
# #10 INT_CONST 123
# #10 '+'
# #10 INT_CONST 1
# #10 '-'
# #10 INT_CONST 1
# #10 '+'
# #10 INT_CONST 90
# #10 '-'
# #10 INT_CONST 09
# #10 '+'
# #10 INT_CONST 11113
# #10 '-'
# #10 INT_CONST 4
# #10 OBJECTID r
# #10 '*'
# #10 OBJECTID a
# #10 '*'
# #10 OBJECTID self
# #10 '*'
# #10 OBJECTID c
# #10 '+'
# #10 '+'
# #11 CLASS
# #11 CLASS
# #11 IF
# #11 THEN
# #11 ELSE
# #11 FI
# #11 OBJECTID testing
# #11 TYPEID Testing
# #11 '~'
# #11 INT_CONST 007
# #11 OBJECTID agent_bond
# #11 OBJECTID james_007bones___
# *)
#
# -------------------------TOKENS--------------------------
# Token(type='OBJECTID', value='factorial', lineno=3, index=51, end=60)
# Token(type='(', value='(', lineno=3, index=60, end=61)
# Token(type='INT_CONST', value=5, lineno=3, index=61, end=62)
# Token(type=')', value=')', lineno=3, index=62, end=63)
# Token(type='=', value='=', lineno=3, index=64, end=65)
# Token(type='INT_CONST', value=120, lineno=3, index=66, end=69)
# Token(type=',', value=',', lineno=3, index=69, end=70)
# Token(type='INT_CONST', value=2, lineno=3, index=71, end=72)
# Token(type='+', value='+', lineno=3, index=73, end=74)
# Token(type='INT_CONST', value=2, lineno=3, index=75, end=76)
# Token(type='=', value='=', lineno=3, index=77, end=78)
# Token(type='INT_CONST', value=5, lineno=3, index=79, end=80)
# Token(type='OBJECTID', value='or', lineno=3, index=81, end=83)
# Token(type='TYPEID', value='E', lineno=3, index=84, end=85)
# Token(type='=', value='=', lineno=3, index=86, end=87)
# Token(type='OBJECTID', value='mc', lineno=3, index=88, end=90)
# ERROR(LexicographicError(3,40): Invalid Character='^')
# Token(type='INT_CONST', value=2, lineno=3, index=91, end=92)
# Token(type=';', value=';', lineno=3, index=92, end=93)
# Token(type='OBJECTID', value='p', lineno=3, index=94, end=95)
# Token(type='+', value='+', lineno=3, index=96, end=97)
# Token(type='INT_CONST', value=1, lineno=3, index=98, end=99)
# Token(type='@', value='@', lineno=3, index=100, end=101)
# Token(type='OBJECTID', value='p', lineno=3, index=102, end=103)
# Token(type='=', value='=', lineno=3, index=104, end=105)
# Token(type='INT_CONST', value=1, lineno=3, index=106, end=107)
# Token(type=':', value=':', lineno=3, index=107, end=108)
# Token(type='OBJECTID', value='z', lineno=3, index=109, end=110)
# Token(type='OBJECTID', value='for', lineno=3, index=111, end=114)
# Token(type='OBJECTID', value='x', lineno=3, index=115, end=116)
# Token(type='IN', value='in', lineno=3, index=117, end=119)
# Token(type='OBJECTID', value='range', lineno=3, index=120, end=125)
# Token(type='(', value='(', lineno=3, index=125, end=126)
# Token(type='OBJECTID', value='len', lineno=3, index=126, end=129)
# Token(type='(', value='(', lineno=3, index=129, end=130)
# Token(type='OBJECTID', value='b', lineno=3, index=130, end=131)
# Token(type=')', value=')', lineno=3, index=131, end=132)
# Token(type=')', value=')', lineno=3, index=132, end=133)
# Token(type=')', value=')', lineno=3, index=133, end=134)
# Token(type='LOOP', value='loop', lineno=5, index=136, end=140)
# Token(type='POOL', value='pool', lineno=5, index=141, end=145)
# Token(type='WHILE', value='while', lineno=5, index=146, end=151)
# Token(type='TRUE', value='tRuE', lineno=5, index=152, end=156)
# Token(type='OBJECTID', value='or', lineno=5, index=157, end=159)
# Token(type='NOT', value='noT', lineno=5, index=160, end=163)
# Token(type='FALSE', value='faLsE', lineno=5, index=164, end=169)
# Token(type='LET', value='let', lineno=5, index=170, end=173)
# Token(type='IN', value='in', lineno=5, index=174, end=176)
# Token(type='CASE', value='case', lineno=5, index=177, end=181)
# Token(type='OF', value='of', lineno=5, index=182, end=184)
# Token(type='ESAC', value='ESAC', lineno=5, index=185, end=189)
# Token(type='NEW', value='new', lineno=7, index=191, end=194)
# Token(type='/', value='/', lineno=7, index=195, end=196)
# Token(type='ASSIGN', value='<-', lineno=7, index=197, end=199)
# Token(type='<', value='<', lineno=7, index=200, end=201)
# Token(type='LE', value='<=', lineno=7, index=201, end=203)
# Token(type='DARROW', value='=>', lineno=7, index=203, end=205)
# Token(type='{', value='{', lineno=7, index=206, end=207)
# Token(type='(', value='(', lineno=7, index=207, end=208)
# Token(type='TYPEID', value='Int', lineno=7, index=209, end=212)
# Token(type=':', value=':', lineno=7, index=212, end=213)
# Token(type='TYPEID', value='Objet', lineno=7, index=214, end=219)
# Token(type=',', value=',', lineno=7, index=219, end=220)
# Token(type='TYPEID', value='Bool', lineno=7, index=221, end=225)
# Token(type=';', value=';', lineno=7, index=225, end=226)
# Token(type='TYPEID', value='String', lineno=7, index=227, end=233)
# Token(type='.', value='.', lineno=7, index=233, end=234)
# Token(type='OBJECTID', value='string', lineno=7, index=234, end=240)
# Token(type='TYPEID', value='SELF_TYPE', lineno=7, index=241, end=250)
# Token(type='ISVOID', value='isvoid', lineno=7, index=251, end=257)
# Token(type='}', value='}', lineno=7, index=258, end=259)
# Token(type=')', value=')', lineno=7, index=259, end=260)
# Token(type='INT_CONST', value=7, lineno=10, index=263, end=267)
# Token(type='INT_CONST', value=123, lineno=10, index=268, end=271)
# Token(type='+', value='+', lineno=10, index=272, end=273)
# Token(type='INT_CONST', value=1, lineno=10, index=273, end=274)
# Token(type='-', value='-', lineno=10, index=275, end=276)
# Token(type='INT_CONST', value=1, lineno=10, index=276, end=277)
# Token(type='+', value='+', lineno=10, index=278, end=279)
# Token(type='INT_CONST', value=90, lineno=10, index=279, end=281)
# Token(type='-', value='-', lineno=10, index=282, end=283)
# Token(type='INT_CONST', value=9, lineno=10, index=283, end=285)
# Token(type='+', value='+', lineno=10, index=286, end=287)
# Token(type='INT_CONST', value=11113, lineno=10, index=287, end=292)
# Token(type='-', value='-', lineno=10, index=293, end=294)
# Token(type='INT_CONST', value=4, lineno=10, index=294, end=295)
# Token(type='OBJECTID', value='r', lineno=10, index=295, end=296)
# Token(type='*', value='*', lineno=10, index=297, end=298)
# Token(type='OBJECTID', value='a', lineno=10, index=298, end=299)
# Token(type='*', value='*', lineno=10, index=300, end=301)
# Token(type='OBJECTID', value='self', lineno=10, index=301, end=305)
# Token(type='*', value='*', lineno=10, index=305, end=306)
# Token(type='OBJECTID', value='c', lineno=10, index=307, end=308)
# Token(type='+', value='+', lineno=10, index=308, end=309)
# Token(type='+', value='+', lineno=10, index=309, end=310)
# Token(type='CLASS', value='class', lineno=11, index=312, end=317)
# Token(type='CLASS', value='Class', lineno=11, index=318, end=323)
# Token(type='IF', value='if', lineno=11, index=324, end=326)
# Token(type='THEN', value='then', lineno=11, index=327, end=331)
# Token(type='ELSE', value='else', lineno=11, index=332, end=336)
# Token(type='FI', value='fi', lineno=11, index=337, end=339)
# Token(type='OBJECTID', value='testing', lineno=11, index=340, end=347)
# Token(type='TYPEID', value='Testing', lineno=11, index=348, end=355)
# Token(type='~', value='~', lineno=11, index=356, end=357)
# Token(type='INT_CONST', value=7, lineno=11, index=357, end=360)
# Token(type='OBJECTID', value='agent_bond', lineno=11, index=360, end=370)
# Token(type='OBJECTID', value='james_007bones___', lineno=11, index=371, end=388)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(3,40): Invalid Character='^')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# (* Integers, Identifiers, and Special Notation *)
#
# new / <- <<==> {( Int: Objet, Bool; String.string SELF_TYPE isvoid })
# 0007 123 +1 -1 +90 -09 +11113 -4r *a *self* c++
#
# factorial(5) = 120, 2 + 2 = 5 or E = mc2; p + 1 % p = 1: @.@ for x in range(len(b))~
#
#
# loop pool while tRuE or noT faLsE let in case of ESAC
# class Class if then else fi testing Testing ~007agent_bond james_007bones___
#
# (*
# #3 NEW
# #3 '/'
# #3 ASSIGN
# #3 '<'
# #3 LE
# #3 DARROW
# #3 '{'
# #3 '('
# #3 TYPEID Int
# #3 ':'
# #3 TYPEID Objet
# #3 ','
# #3 TYPEID Bool
# #3 ';'
# #3 TYPEID String
# #3 '.'
# #3 OBJECTID string
# #3 TYPEID SELF_TYPE
# #3 ISVOID
# #3 '}'
# #3 ')'
# #4 INT_CONST 0007
# #4 INT_CONST 123
# #4 '+'
# #4 INT_CONST 1
# #4 '-'
# #4 INT_CONST 1
# #4 '+'
# #4 INT_CONST 90
# #4 '-'
# #4 INT_CONST 09
# #4 '+'
# #4 INT_CONST 11113
# #4 '-'
# #4 INT_CONST 4
# #4 OBJECTID r
# #4 '*'
# #4 OBJECTID a
# #4 '*'
# #4 OBJECTID self
# #4 '*'
# #4 OBJECTID c
# #4 '+'
# #4 '+'
# #6 OBJECTID factorial
# #6 '('
# #6 INT_CONST 5
# #6 ')'
# #6 '='
# #6 INT_CONST 120
# #6 ','
# #6 INT_CONST 2
# #6 '+'
# #6 INT_CONST 2
# #6 '='
# #6 INT_CONST 5
# #6 OBJECTID or
# #6 TYPEID E
# #6 '='
# #6 OBJECTID mc2
# #6 ';'
# #6 OBJECTID p
# #6 '+'
# #6 INT_CONST 1
# #6 ERROR "%"
# #6 OBJECTID p
# #6 '='
# #6 INT_CONST 1
# #6 ':'
# #6 '@'
# #6 '.'
# #6 '@'
# #6 OBJECTID for
# #6 OBJECTID x
# #6 IN
# #6 OBJECTID range
# #6 '('
# #6 OBJECTID len
# #6 '('
# #6 OBJECTID b
# #6 ')'
# #6 ')'
# #6 '~'
# #9 LOOP
# #9 POOL
# #9 WHILE
# #9 BOOL_CONST true
# #9 OBJECTID or
# #9 NOT
# #9 BOOL_CONST false
# #9 LET
# #9 IN
# #9 CASE
# #9 OF
# #9 ESAC
# #10 CLASS
# #10 CLASS
# #10 IF
# #10 THEN
# #10 ELSE
# #10 FI
# #10 OBJECTID testing
# #10 TYPEID Testing
# #10 '~'
# #10 INT_CONST 007
# #10 OBJECTID agent_bond
# #10 OBJECTID james_007bones___
# *)
#
# -------------------------TOKENS--------------------------
# Token(type='NEW', value='new', lineno=3, index=51, end=54)
# Token(type='/', value='/', lineno=3, index=55, end=56)
# Token(type='ASSIGN', value='<-', lineno=3, index=57, end=59)
# Token(type='<', value='<', lineno=3, index=60, end=61)
# Token(type='LE', value='<=', lineno=3, index=61, end=63)
# Token(type='DARROW', value='=>', lineno=3, index=63, end=65)
# Token(type='{', value='{', lineno=3, index=66, end=67)
# Token(type='(', value='(', lineno=3, index=67, end=68)
# Token(type='TYPEID', value='Int', lineno=3, index=69, end=72)
# Token(type=':', value=':', lineno=3, index=72, end=73)
# Token(type='TYPEID', value='Objet', lineno=3, index=74, end=79)
# Token(type=',', value=',', lineno=3, index=79, end=80)
# Token(type='TYPEID', value='Bool', lineno=3, index=81, end=85)
# Token(type=';', value=';', lineno=3, index=85, end=86)
# Token(type='TYPEID', value='String', lineno=3, index=87, end=93)
# Token(type='.', value='.', lineno=3, index=93, end=94)
# Token(type='OBJECTID', value='string', lineno=3, index=94, end=100)
# Token(type='TYPEID', value='SELF_TYPE', lineno=3, index=101, end=110)
# Token(type='ISVOID', value='isvoid', lineno=3, index=111, end=117)
# Token(type='}', value='}', lineno=3, index=118, end=119)
# Token(type=')', value=')', lineno=3, index=119, end=120)
# Token(type='INT_CONST', value=7, lineno=4, index=121, end=125)
# Token(type='INT_CONST', value=123, lineno=4, index=126, end=129)
# Token(type='+', value='+', lineno=4, index=130, end=131)
# Token(type='INT_CONST', value=1, lineno=4, index=131, end=132)
# Token(type='-', value='-', lineno=4, index=133, end=134)
# Token(type='INT_CONST', value=1, lineno=4, index=134, end=135)
# Token(type='+', value='+', lineno=4, index=136, end=137)
# Token(type='INT_CONST', value=90, lineno=4, index=137, end=139)
# Token(type='-', value='-', lineno=4, index=140, end=141)
# Token(type='INT_CONST', value=9, lineno=4, index=141, end=143)
# Token(type='+', value='+', lineno=4, index=144, end=145)
# Token(type='INT_CONST', value=11113, lineno=4, index=145, end=150)
# Token(type='-', value='-', lineno=4, index=151, end=152)
# Token(type='INT_CONST', value=4, lineno=4, index=152, end=153)
# Token(type='OBJECTID', value='r', lineno=4, index=153, end=154)
# Token(type='*', value='*', lineno=4, index=155, end=156)
# Token(type='OBJECTID', value='a', lineno=4, index=156, end=157)
# Token(type='*', value='*', lineno=4, index=158, end=159)
# Token(type='OBJECTID', value='self', lineno=4, index=159, end=163)
# Token(type='*', value='*', lineno=4, index=163, end=164)
# Token(type='OBJECTID', value='c', lineno=4, index=165, end=166)
# Token(type='+', value='+', lineno=4, index=166, end=167)
# Token(type='+', value='+', lineno=4, index=167, end=168)
# Token(type='OBJECTID', value='factorial', lineno=6, index=171, end=180)
# Token(type='(', value='(', lineno=6, index=180, end=181)
# Token(type='INT_CONST', value=5, lineno=6, index=181, end=182)
# Token(type=')', value=')', lineno=6, index=182, end=183)
# Token(type='=', value='=', lineno=6, index=184, end=185)
# Token(type='INT_CONST', value=120, lineno=6, index=186, end=189)
# Token(type=',', value=',', lineno=6, index=189, end=190)
# Token(type='INT_CONST', value=2, lineno=6, index=191, end=192)
# Token(type='+', value='+', lineno=6, index=193, end=194)
# Token(type='INT_CONST', value=2, lineno=6, index=195, end=196)
# Token(type='=', value='=', lineno=6, index=197, end=198)
# Token(type='INT_CONST', value=5, lineno=6, index=199, end=200)
# Token(type='OBJECTID', value='or', lineno=6, index=201, end=203)
# Token(type='TYPEID', value='E', lineno=6, index=204, end=205)
# Token(type='=', value='=', lineno=6, index=206, end=207)
# Token(type='OBJECTID', value='mc2', lineno=6, index=208, end=211)
# Token(type=';', value=';', lineno=6, index=211, end=212)
# Token(type='OBJECTID', value='p', lineno=6, index=213, end=214)
# Token(type='+', value='+', lineno=6, index=215, end=216)
# Token(type='INT_CONST', value=1, lineno=6, index=217, end=218)
# ERROR(LexicographicError(6,49): Invalid Character='%')
# Token(type='OBJECTID', value='p', lineno=6, index=221, end=222)
# Token(type='=', value='=', lineno=6, index=223, end=224)
# Token(type='INT_CONST', value=1, lineno=6, index=225, end=226)
# Token(type=':', value=':', lineno=6, index=226, end=227)
# Token(type='@', value='@', lineno=6, index=228, end=229)
# Token(type='.', value='.', lineno=6, index=229, end=230)
# Token(type='@', value='@', lineno=6, index=230, end=231)
# Token(type='OBJECTID', value='for', lineno=6, index=232, end=235)
# Token(type='OBJECTID', value='x', lineno=6, index=236, end=237)
# Token(type='IN', value='in', lineno=6, index=238, end=240)
# Token(type='OBJECTID', value='range', lineno=6, index=241, end=246)
# Token(type='(', value='(', lineno=6, index=246, end=247)
# Token(type='OBJECTID', value='len', lineno=6, index=247, end=250)
# Token(type='(', value='(', lineno=6, index=250, end=251)
# Token(type='OBJECTID', value='b', lineno=6, index=251, end=252)
# Token(type=')', value=')', lineno=6, index=252, end=253)
# Token(type=')', value=')', lineno=6, index=253, end=254)
# Token(type='~', value='~', lineno=6, index=254, end=255)
# Token(type='LOOP', value='loop', lineno=9, index=258, end=262)
# Token(type='POOL', value='pool', lineno=9, index=263, end=267)
# Token(type='WHILE', value='while', lineno=9, index=268, end=273)
# Token(type='TRUE', value='tRuE', lineno=9, index=274, end=278)
# Token(type='OBJECTID', value='or', lineno=9, index=279, end=281)
# Token(type='NOT', value='noT', lineno=9, index=282, end=285)
# Token(type='FALSE', value='faLsE', lineno=9, index=286, end=291)
# Token(type='LET', value='let', lineno=9, index=292, end=295)
# Token(type='IN', value='in', lineno=9, index=296, end=298)
# Token(type='CASE', value='case', lineno=9, index=299, end=303)
# Token(type='OF', value='of', lineno=9, index=304, end=306)
# Token(type='ESAC', value='ESAC', lineno=9, index=307, end=311)
# Token(type='CLASS', value='class', lineno=10, index=312, end=317)
# Token(type='CLASS', value='Class', lineno=10, index=318, end=323)
# Token(type='IF', value='if', lineno=10, index=324, end=326)
# Token(type='THEN', value='then', lineno=10, index=327, end=331)
# Token(type='ELSE', value='else', lineno=10, index=332, end=336)
# Token(type='FI', value='fi', lineno=10, index=337, end=339)
# Token(type='OBJECTID', value='testing', lineno=10, index=340, end=347)
# Token(type='TYPEID', value='Testing', lineno=10, index=348, end=355)
# Token(type='~', value='~', lineno=10, index=356, end=357)
# Token(type='INT_CONST', value=7, lineno=10, index=357, end=360)
# Token(type='OBJECTID', value='agent_bond', lineno=10, index=360, end=370)
# Token(type='OBJECTID', value='james_007bones___', lineno=10, index=371, end=388)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(6,49): Invalid Character='%')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# (* A string may not contain EOF *)
#
# "               May the Triforce              \
#                       0                       \
#                      0v0                      \
#                     0vvv0                     \
#                    0vvvvv0                    \
#                   0vvvvvvv0                   \
#                  0vvvvvvvvv0                  \
#                 0vvvvvvvvvvv0                 \
#                000000000000000                \
#               0v0           0v0               \
#              0vvv0         0vvv0              \
#             0vvvvv0       0vvvvv0             \
#            0vvvvvvv0     0vvvvvvv0            \
#           0vvvvvvvvv0   0vvvvvvvvv0           \
#          0vvvvvvvvvvv0 0vvvvvvvvvvv0          \
#         00000000000000000000000000000         \
#                 be with you!
#
# -------------------------TOKENS--------------------------
# ERROR(LexicographicError(19,29): EOF in string constant='... with you!')
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(19,29): EOF in string constant='... with you!')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# (* A non-escaped newline character may not appear in a string *)
#
# "This \
# is OK"
# "This is not
# OK"
#
# -------------------------TOKENS--------------------------
# TOKEN(type='STRING', value = '"This is OK"', lineno = 4, index = 66, end = 81)
# ERROR(LexicographicError(5,13): Unterminated string constant='...his is not')
# Token(type='TYPEID', value='OK', lineno=6, index=94, end=96)
# ERROR(LexicographicError(6,4): EOF in string constant='"')
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(5,13): Unterminated string constant='...his is not')
# ERROR(LexicographicError(6,4): EOF in string constant='"')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# class Main {
#     str <- "The big brown fox
#             jumped over the fence";
# 	main() : Object {
#         {
#             out_string("Yay! This is the newest shites );
#         }
#     };
# };
#
# (*
# #1 CLASS
# #1 TYPEID Main
# #1 '{'
# #2 OBJECTID str
# #2 ASSIGN
# #3 ERROR "Unterminated string constant"
# #3 OBJECTID jumped
# #3 OBJECTID over
# #3 OBJECTID the
# #3 OBJECTID fence
# #4 ERROR "Unterminated string constant"
# #4 OBJECTID main
# #4 '('
# #4 ')'
# #4 ':'
# #4 TYPEID Object
# #4 '{'
# #5 '{'
# #6 OBJECTID out_string
# #6 '('
# #7 ERROR "Unterminated string constant"
# #7 '}'
# #8 '}'
# #8 ';'
# #9 '}'
# #9 ';'
# *)
#
# -------------------------TOKENS--------------------------
# Token(type='CLASS', value='class', lineno=1, index=0, end=5)
# Token(type='TYPEID', value='Main', lineno=1, index=6, end=10)
# Token(type='{', value='{', lineno=1, index=11, end=12)
# Token(type='OBJECTID', value='str', lineno=2, index=17, end=20)
# Token(type='ASSIGN', value='<-', lineno=2, index=21, end=23)
# ERROR(LexicographicError(2,30): Unterminated string constant='... brown fox')
# Token(type='OBJECTID', value='jumped', lineno=3, index=55, end=61)
# Token(type='OBJECTID', value='over', lineno=3, index=62, end=66)
# Token(type='OBJECTID', value='the', lineno=3, index=67, end=70)
# Token(type='OBJECTID', value='fence', lineno=3, index=71, end=76)
# ERROR(LexicographicError(3,36): Unterminated string constant='";')
# Token(type='OBJECTID', value='main', lineno=4, index=80, end=84)
# Token(type='(', value='(', lineno=4, index=84, end=85)
# Token(type=')', value=')', lineno=4, index=85, end=86)
# Token(type=':', value=':', lineno=4, index=87, end=88)
# Token(type='TYPEID', value='Object', lineno=4, index=89, end=95)
# Token(type='{', value='{', lineno=4, index=96, end=97)
# Token(type='{', value='{', lineno=5, index=106, end=107)
# Token(type='OBJECTID', value='out_string', lineno=6, index=120, end=130)
# Token(type='(', value='(', lineno=6, index=130, end=131)
# ERROR(LexicographicError(6,58): Unterminated string constant='... shites );')
# Token(type='}', value='}', lineno=7, index=174, end=175)
# Token(type='}', value='}', lineno=8, index=180, end=181)
# Token(type=';', value=';', lineno=8, index=181, end=182)
# Token(type='}', value='}', lineno=9, index=183, end=184)
# Token(type=';', value=';', lineno=9, index=184, end=185)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(2,30): Unterminated string constant='... brown fox')
# ERROR(LexicographicError(3,36): Unterminated string constant='";')
# ERROR(LexicographicError(6,58): Unterminated string constant='... shites );')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
#
# (* A string may not contain the null (character \0). Any other character
# may be included in a string *)
#
# "lkjdsafkljdsalfj\u0000dsafdsaf\u0000djafslkjdsalf\nsdajf\" lkjfdsasdkjfl" algoritmo "\b\f\s123\t"
# adsfasklj
# LKldsajf
# "lkdsajf"
#
# -------------------------TOKENS--------------------------
# TOKEN(type='STRING', value = '"lkjdsafkljdsalfju0000dsafdsafu0000djafslkjdsalf\nsdajf" lkjfdsasdkjfl"', lineno = 4, index = 106, end = 181)
# Token(type='OBJECTID', value='algoritmo', lineno=4, index=181, end=190)
# TOKEN(type='STRING', value = '"bfs123t"', lineno = 4, index = 191, end = 205)
# Token(type='OBJECTID', value='adsfasklj', lineno=5, index=205, end=214)
# Token(type='TYPEID', value='LKldsajf', lineno=6, index=215, end=223)
# ERROR(LexicographicError(7,4): String contains null character='"lk\0dsajf"')
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(7,4): String contains null character='"lk\0dsajf"')
# _____________________________________________________________________________________________________
#
#
#
# --------------------------CASE---------------------------
# (* Integers, Identifiers, and Special Notation *)
#
# 0007 123 +1 -1 +90 -09 +11113 -4r *a *self* c++
# class Class if then else fi testing Testing ~007agent_bond james_007bones___
#
#
# new / <- <<==> {( Int: Objet, Bool; String.string SELF_TYPE isvoid })
# loop pool while tRuE or noT faLsE let in case of ESAC
#
# factorial(5) = 120, 2 + 2 = 5? or E = mc2; p + 1 resto p = 1: (@ for x in range(len(b)))
#
# (*
# #3 INT_CONST 0007
# #3 INT_CONST 123
# #3 '+'
# #3 INT_CONST 1
# #3 '-'
# #3 INT_CONST 1
# #3 '+'
# #3 INT_CONST 90
# #3 '-'
# #3 INT_CONST 09
# #3 '+'
# #3 INT_CONST 11113
# #3 '-'
# #3 INT_CONST 4
# #3 OBJECTID r
# #3 '*'
# #3 OBJECTID a
# #3 '*'
# #3 OBJECTID self
# #3 '*'
# #3 OBJECTID c
# #3 '+'
# #3 '+'
# #4 CLASS
# #4 CLASS
# #4 IF
# #4 THEN
# #4 ELSE
# #4 FI
# #4 OBJECTID testing
# #4 TYPEID Testing
# #4 '~'
# #4 INT_CONST 007
# #4 OBJECTID agent_bond
# #4 OBJECTID james_007bones___
# #7 NEW
# #7 '/'
# #7 ASSIGN
# #7 '<'
# #7 LE
# #7 DARROW
# #7 '{'
# #7 '('
# #7 TYPEID Int
# #7 ':'
# #7 TYPEID Objet
# #7 ','
# #7 TYPEID Bool
# #7 ';'
# #7 TYPEID String
# #7 '.'
# #7 OBJECTID string
# #7 TYPEID SELF_TYPE
# #7 ISVOID
# #7 '}'
# #7 ')'
# #8 LOOP
# #8 POOL
# #8 WHILE
# #8 BOOL_CONST true
# #8 OBJECTID or
# #8 NOT
# #8 BOOL_CONST false
# #8 LET
# #8 IN
# #8 CASE
# #8 OF
# #8 ESAC
# #10 OBJECTID factorial
# #10 '('
# #10 INT_CONST 5
# #10 ')'
# #10 '='
# #10 INT_CONST 120
# #10 ','
# #10 INT_CONST 2
# #10 '+'
# #10 INT_CONST 2
# #10 '='
# #10 INT_CONST 5
# #10 ERROR "?"
# #10 OBJECTID or
# #10 TYPEID E
# #10 '='
# #10 OBJECTID mc2
# #10 ';'
# #10 OBJECTID p
# #10 '+'
# #10 INT_CONST 1
# #10 OBJECTID resto
# #10 OBJECTID p
# #10 '='
# #10 INT_CONST 1
# #10 ':'
# #10 '('
# #10 '@'
# #10 OBJECTID for
# #10 OBJECTID x
# #10 IN
# #10 OBJECTID range
# #10 '('
# #10 OBJECTID len
# #10 '('
# #10 OBJECTID b
# #10 ')'
# #10 ')'
# #10 ')'
# *)
#
# -------------------------TOKENS--------------------------
# Token(type='INT_CONST', value=7, lineno=3, index=51, end=55)
# Token(type='INT_CONST', value=123, lineno=3, index=56, end=59)
# Token(type='+', value='+', lineno=3, index=60, end=61)
# Token(type='INT_CONST', value=1, lineno=3, index=61, end=62)
# Token(type='-', value='-', lineno=3, index=63, end=64)
# Token(type='INT_CONST', value=1, lineno=3, index=64, end=65)
# Token(type='+', value='+', lineno=3, index=66, end=67)
# Token(type='INT_CONST', value=90, lineno=3, index=67, end=69)
# Token(type='-', value='-', lineno=3, index=70, end=71)
# Token(type='INT_CONST', value=9, lineno=3, index=71, end=73)
# Token(type='+', value='+', lineno=3, index=74, end=75)
# Token(type='INT_CONST', value=11113, lineno=3, index=75, end=80)
# Token(type='-', value='-', lineno=3, index=81, end=82)
# Token(type='INT_CONST', value=4, lineno=3, index=82, end=83)
# Token(type='OBJECTID', value='r', lineno=3, index=83, end=84)
# Token(type='*', value='*', lineno=3, index=85, end=86)
# Token(type='OBJECTID', value='a', lineno=3, index=86, end=87)
# Token(type='*', value='*', lineno=3, index=88, end=89)
# Token(type='OBJECTID', value='self', lineno=3, index=89, end=93)
# Token(type='*', value='*', lineno=3, index=93, end=94)
# Token(type='OBJECTID', value='c', lineno=3, index=95, end=96)
# Token(type='+', value='+', lineno=3, index=96, end=97)
# Token(type='+', value='+', lineno=3, index=97, end=98)
# Token(type='CLASS', value='class', lineno=4, index=100, end=105)
# Token(type='CLASS', value='Class', lineno=4, index=106, end=111)
# Token(type='IF', value='if', lineno=4, index=112, end=114)
# Token(type='THEN', value='then', lineno=4, index=115, end=119)
# Token(type='ELSE', value='else', lineno=4, index=120, end=124)
# Token(type='FI', value='fi', lineno=4, index=125, end=127)
# Token(type='OBJECTID', value='testing', lineno=4, index=128, end=135)
# Token(type='TYPEID', value='Testing', lineno=4, index=136, end=143)
# Token(type='~', value='~', lineno=4, index=144, end=145)
# Token(type='INT_CONST', value=7, lineno=4, index=145, end=148)
# Token(type='OBJECTID', value='agent_bond', lineno=4, index=148, end=158)
# Token(type='OBJECTID', value='james_007bones___', lineno=4, index=159, end=176)
# Token(type='NEW', value='new', lineno=7, index=179, end=182)
# Token(type='/', value='/', lineno=7, index=183, end=184)
# Token(type='ASSIGN', value='<-', lineno=7, index=185, end=187)
# Token(type='<', value='<', lineno=7, index=188, end=189)
# Token(type='LE', value='<=', lineno=7, index=189, end=191)
# Token(type='DARROW', value='=>', lineno=7, index=191, end=193)
# Token(type='{', value='{', lineno=7, index=194, end=195)
# Token(type='(', value='(', lineno=7, index=195, end=196)
# Token(type='TYPEID', value='Int', lineno=7, index=197, end=200)
# Token(type=':', value=':', lineno=7, index=200, end=201)
# Token(type='TYPEID', value='Objet', lineno=7, index=202, end=207)
# Token(type=',', value=',', lineno=7, index=207, end=208)
# Token(type='TYPEID', value='Bool', lineno=7, index=209, end=213)
# Token(type=';', value=';', lineno=7, index=213, end=214)
# Token(type='TYPEID', value='String', lineno=7, index=215, end=221)
# Token(type='.', value='.', lineno=7, index=221, end=222)
# Token(type='OBJECTID', value='string', lineno=7, index=222, end=228)
# Token(type='TYPEID', value='SELF_TYPE', lineno=7, index=229, end=238)
# Token(type='ISVOID', value='isvoid', lineno=7, index=239, end=245)
# Token(type='}', value='}', lineno=7, index=246, end=247)
# Token(type=')', value=')', lineno=7, index=247, end=248)
# Token(type='LOOP', value='loop', lineno=8, index=249, end=253)
# Token(type='POOL', value='pool', lineno=8, index=254, end=258)
# Token(type='WHILE', value='while', lineno=8, index=259, end=264)
# Token(type='TRUE', value='tRuE', lineno=8, index=265, end=269)
# Token(type='OBJECTID', value='or', lineno=8, index=270, end=272)
# Token(type='NOT', value='noT', lineno=8, index=273, end=276)
# Token(type='FALSE', value='faLsE', lineno=8, index=277, end=282)
# Token(type='LET', value='let', lineno=8, index=283, end=286)
# Token(type='IN', value='in', lineno=8, index=287, end=289)
# Token(type='CASE', value='case', lineno=8, index=290, end=294)
# Token(type='OF', value='of', lineno=8, index=295, end=297)
# Token(type='ESAC', value='ESAC', lineno=8, index=298, end=302)
# Token(type='OBJECTID', value='factorial', lineno=10, index=304, end=313)
# Token(type='(', value='(', lineno=10, index=313, end=314)
# Token(type='INT_CONST', value=5, lineno=10, index=314, end=315)
# Token(type=')', value=')', lineno=10, index=315, end=316)
# Token(type='=', value='=', lineno=10, index=317, end=318)
# Token(type='INT_CONST', value=120, lineno=10, index=319, end=322)
# Token(type=',', value=',', lineno=10, index=322, end=323)
# Token(type='INT_CONST', value=2, lineno=10, index=324, end=325)
# Token(type='+', value='+', lineno=10, index=326, end=327)
# Token(type='INT_CONST', value=2, lineno=10, index=328, end=329)
# Token(type='=', value='=', lineno=10, index=330, end=331)
# Token(type='INT_CONST', value=5, lineno=10, index=332, end=333)
# ERROR(LexicographicError(10,30): Invalid Character='?')
# Token(type='OBJECTID', value='or', lineno=10, index=335, end=337)
# Token(type='TYPEID', value='E', lineno=10, index=338, end=339)
# Token(type='=', value='=', lineno=10, index=340, end=341)
# Token(type='OBJECTID', value='mc2', lineno=10, index=342, end=345)
# Token(type=';', value=';', lineno=10, index=345, end=346)
# Token(type='OBJECTID', value='p', lineno=10, index=347, end=348)
# Token(type='+', value='+', lineno=10, index=349, end=350)
# Token(type='INT_CONST', value=1, lineno=10, index=351, end=352)
# Token(type='OBJECTID', value='resto', lineno=10, index=353, end=358)
# Token(type='OBJECTID', value='p', lineno=10, index=359, end=360)
# Token(type='=', value='=', lineno=10, index=361, end=362)
# Token(type='INT_CONST', value=1, lineno=10, index=363, end=364)
# Token(type=':', value=':', lineno=10, index=364, end=365)
# Token(type='(', value='(', lineno=10, index=366, end=367)
# Token(type='@', value='@', lineno=10, index=367, end=368)
# Token(type='OBJECTID', value='for', lineno=10, index=369, end=372)
# Token(type='OBJECTID', value='x', lineno=10, index=373, end=374)
# Token(type='IN', value='in', lineno=10, index=375, end=377)
# Token(type='OBJECTID', value='range', lineno=10, index=378, end=383)
# Token(type='(', value='(', lineno=10, index=383, end=384)
# Token(type='OBJECTID', value='len', lineno=10, index=384, end=387)
# Token(type='(', value='(', lineno=10, index=387, end=388)
# Token(type='OBJECTID', value='b', lineno=10, index=388, end=389)
# Token(type=')', value=')', lineno=10, index=389, end=390)
# Token(type=')', value=')', lineno=10, index=390, end=391)
# Token(type=')', value=')', lineno=10, index=391, end=392)
#
# -----------------------ERRORS--------------------------
# ERROR(LexicographicError(10,30): Invalid Character='?')
# _____________________________________________________________________________________________________

# %% [markdown]
# # Parser

# %%
# Tests para parser
