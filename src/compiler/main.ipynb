# %% [markdown]
# # Lexer

# %% [markdown]
# ##### Basic test case

# %%
from lexer.cool_lexer import CoolLexer
import os
case = "iis1.cl"


base_dir = os.getcwd()
base_url = os.path.join(base_dir[:-13], "tests/lexer/")

dir = '/'.join([base_url,case])
with open(dir, "r") as f:
    content = f.read()
print("--------------------------CASE---------------------------")
print(content, end="\n\n")

print("-------------------------TOKENS--------------------------")
lexer = CoolLexer()
for token in lexer.tokenize(content):
    print(token)

print("\n-----------------------ERRORS--------------------------")
for e in lexer.errors:
    print(e)

# %% [markdown]
# ##### Run all test cases

# %%
from lexer.cool_lexer import CoolLexer
import os

base_dir = os.getcwd()
base_url = os.path.join(base_dir[:-13], "tests/lexer/")

cases = [case for case in os.listdir(base_url) if case.endswith('.cl')] 
for case in cases:
    dir = '/'.join([base_url,case])
    with open(dir, "r") as f:
        content = f.read()
    print("--------------------------CASE---------------------------")
    print(content, end="\n\n")

    print("-------------------------TOKENS--------------------------")
    lexer = CoolLexer()
    for token in lexer.tokenize(content):
        print(token)

    print("\n-----------------------ERRORS--------------------------")
    for e in lexer.errors:
        print(e)
    print("_____________________________________________________________________________________________________")
    print('\n\n')

# %% [markdown]
# # Parser

# %% [markdown]
# ##### casos de prueba manuales

# %%
from parser.cool_parser import CoolLexer, CoolParser

lexer = CoolLexer()
parser = CoolParser(lexer = lexer)
############ ---------------------------------------------expr------------------------------------------------------------############
_while = 'while (3 + 5) * 6 < 17 + 18 * (false - true) loop if not if true then 1 else 0 fi then false else 18 fi pool'
_if = 'if not if true then ~(1 + 4 * 2) else 0 fi then false else 18 fi'
_let = 'let a:STRING <- "asd", b:STRING <- "qwe", c:STRING <- "zxc" in {New INT; a + b * c;}'
_id_call = 'x(a,b,c, 3+4)'
_block = '{New INT; a + b * c; let a:STRING <- "asd" in a; case x of a:STRING => 1; b:STRING => 1; c:STRING => 1; esac; }'
_case = 'case x of a:STRING => 1; b:STRING => 1; c:STRING => 1; esac'
_full_block = '{'+ f'{_if}; {_let}; {_block}; {_case}; {_while};' + '}'
_assign = 'a <- 4'
_object_method = '{ c.a(); c@INT.a();c@INT.a(x, 2, 6*8);}'
############ ------------------------------------------program class-------------------------------------------------------############
scope = '{a<-1; b<-2; c<-a+b; case x of a:INT => 1; b:INT => 1; c:INT => 1; esac; }'
_def = 'f(q:INT, w:INT):INT {'+ scope +'}'
_class1 = 'class MyClass1 { a:INT <- 1; f(x:INT):INT { print(x) }; }'
_class2 = 'class MyClass2 { b:INT <- 2; f(y:INT):INT { {y<-y+1; print(y + 3);} }; }'
_program = f'{_class1};{_class2};'
#-------------------------------------------------------------------------------------------------------------------------------------#

result = parser.parse(lexer.tokenize(_program))
result.show_tree()

# %% [markdown]
# ##### casos de prueba de los testers seleccinando uno dado

# %%
#select the test case that do you want analize, index could be >= 1
index_test = 5
show_ast = True

#region ############# ---------Code Region--------- ################
from parser.cool_parser import CoolLexer, CoolParser, Node
import os
lexer = CoolLexer()

parser = CoolParser(lexer = lexer)
base_dir = os.getcwd()
base_url = os.path.join(base_dir[:-13], "tests/parser/")
cases = [case for case in os.listdir(base_url) if case.endswith('.cl')] 
cases.sort()
case = cases[index_test-1]
case_error = case[:-3] + '_error.txt'
dir = '/'.join([base_url,case])
dir_error = '/'.join([base_url,case_error])
with open(dir, "r") as f:
    code = f.read()
with open(dir_error, "r") as f:
    error = f.read()
# endregion

PROGRAM:Node = parser.parse(lexer.tokenize(code))
if len(parser.errors) == 0 and show_ast:
    PROGRAM.show_tree()

print('\n------------------PARSER ERRORS------------------')
for e in parser.errors:
    print(e)
print ("\n------------------EXPECTED ERRORS:---------------")
print(error)

# %% [markdown]
# ##### Todos los casos de prueba de los testers

# %%
from parser.cool_parser import CoolLexer, CoolParser, Node
import os

base_dir = os.getcwd()
base_url = os.path.join(base_dir[:-13], "tests/parser/")
cases = [case for case in os.listdir(base_url) if case.endswith('.cl')] 
cases.sort()

for i in range(len(cases)):
    case = cases[i]
    case_error = case[:-3] + '_error.txt'
    dir = '/'.join([base_url,case])
    dir_error = '/'.join([base_url,case_error])
    with open(dir, "r") as f:
        code = f.read()
    with open(dir_error, "r") as f:
        error = f.read()

    lexer = CoolLexer()
    parser = CoolParser(lexer = lexer)

    PROGRAM:Node = parser.parse(lexer.tokenize(code))

    print(f'\n\n\n######################### CASE {i+1} #############################')
    print('----------------------PARSER ERRORS---------------------------')
    for e in parser.errors:
        print(e)
    print ("\n---------------------EXPECTED ERRORS:-------------------------")
    print(error)
# Out:
# ######################### CASE 1 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(29,9): ERROR at or near 'Test1')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (29, 9) - SyntacticError: ERROR at or near "Test1"
#
#
#
# ######################### CASE 2 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(29,17): ERROR at or near '-')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (29, 17) - SyntacticError: ERROR at or near "-"
#
#
#
# ######################### CASE 3 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(29,23): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (29, 23) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 4 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(17,5): ERROR at or near 'Test2')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (17, 5) - SyntacticError: ERROR at or near "Test2"
#
#
#
# ######################### CASE 5 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(19,12): ERROR at or near 'string')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (19, 12) - SyntacticError: ERROR at or near "string"
#
#
#
# ######################### CASE 6 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(19,19): ERROR at or near '<=')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (19, 19) - SyntacticError: ERROR at or near "<="
#
#
#
# ######################### CASE 7 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(56,17): ERROR at or near '}')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (56, 17) - SyntacticError: ERROR at or near "}"
#
#
#
# ######################### CASE 8 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(49,23): ERROR at or near ';')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (49, 23) - SyntacticError: ERROR at or near ";"
#
#
#
# ######################### CASE 9 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(57,13): ERROR at or near 'pool')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (57, 13) - SyntacticError: ERROR at or near "pool"
#
#
#
# ######################### CASE 10 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(56,26): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (56, 26) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 11 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(63,9): ERROR at or near 'esac')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (63, 9) - SyntacticError: ERROR at or near ESAC
#
#
#
# ######################### CASE 12 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(63,13): ERROR at or near 'y')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (63, 13) - SyntacticError: ERROR at or near "y"
#
#
#
# ######################### CASE 13 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(63,16): ERROR at or near 'string')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (63, 16) - SyntacticError: ERROR at or near "string"
#
#
#
# ######################### CASE 14 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(64,13): ERROR at or near 'Mazinger_Z')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (64, 13) - SyntacticError: ERROR at or near "Mazinger_Z"
#
#
#
# ######################### CASE 15 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(62,20): ERROR at or near '<-')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (62, 20) - SyntacticError: ERROR at or near ASSIGN
#
#
#
# ######################### CASE 16 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(62,13): ERROR at or near 'x')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (62, 13) - SyntacticError: ERROR at or near "x"
#
#
#
# ######################### CASE 17 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(16,7): ERROR at or near 'alpha')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (16, 7) - SyntacticError: ERROR at or near "alpha"
#
#
#
# ######################### CASE 18 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(16,22): ERROR at or near 'iO')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (16, 22) - SyntacticError: ERROR at or near "iO"
#
#
#
# ######################### CASE 19 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(25,5): ERROR at or near 'testing3')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (25, 5) - SyntacticError: ERROR at or near "testing3"
#
#
#
# ######################### CASE 20 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(25,5): ERROR at or near '2')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (25, 5) - SyntacticError: ERROR at or near "2"
#
#
#
# ######################### CASE 21 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(11,5): ERROR at or near 'test1')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (11, 5) - SyntacticError: ERROR at or near "test1"
#
#
#
# ######################### CASE 22 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(28,1): ERROR at or near ';')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (28, 1) - SyntacticError: ERROR at or near ";"
#
#
#
# ######################### CASE 23 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(34,13): ERROR at or near 'new')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (34, 13) - SyntacticError: ERROR at or near NEW
#
#
#
# ######################### CASE 24 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(42,5): ERROR at or near '}')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (42, 5) - SyntacticError: ERROR at or near "}"
#
#
#
# ######################### CASE 25 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(38,13): ERROR at or near 'eLseif')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (38, 13) - SyntacticError: ERROR at or near "eLseif"
#
#
#
# ######################### CASE 26 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,17): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 17) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 27 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,27): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 27) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 28 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,35): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 35) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 29 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(37,9): ERROR at or near 'Test1')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (37, 9) - SyntacticError: ERROR at or near "Test1"
#
#
#
# ######################### CASE 30 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(37,84): ERROR at or near ')')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (37, 84) - SyntacticError: ERROR at or near ")"
#
#
#
# ######################### CASE 31 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(37,38): ERROR at or near 'Testing4')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (37, 38) - SyntacticError: ERROR at or near "Testing4"
#
#
#
# ######################### CASE 32 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,81): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 81) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 33 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,71): ERROR at or near ',')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 71) - SyntacticError: ERROR at or near ","
#
#
#
# ######################### CASE 34 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(49,15): ERROR at or near 'object')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (49, 15) - SyntacticError: ERROR at or near "object"
#
#
#
# ######################### CASE 35 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(49,22): ERROR at or near 'Copy')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (49, 22) - SyntacticError: ERROR at or near "Copy"
#
#
#
# ######################### CASE 36 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(49,27): ERROR at or near ',')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (49, 27) - SyntacticError: ERROR at or near ","
#
#
#
# ######################### CASE 37 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(53,14): ERROR at or near ':')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (53, 14) - SyntacticError: ERROR at or near ":"
#
#
#
# ######################### CASE 38 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,13): ERROR at or near 'Count')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 13) - SyntacticError: ERROR at or near "Count"
#
#
#
# ######################### CASE 39 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,30): ERROR at or near 'int')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 30) - SyntacticError: ERROR at or near "int"
#
#
#
# ######################### CASE 40 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(46,9): ERROR at or near 'in')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (46, 9) - SyntacticError: ERROR at or near IN
#
#
#
# ######################### CASE 41 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,32): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 32) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 42 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(45,24): ERROR at or near '=')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (45, 24) - SyntacticError: ERROR at or near "="
#
#
#
# ######################### CASE 43 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(46,18): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (46, 18) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 44 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(46,28): ERROR at or near '{')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (46, 28) - SyntacticError: ERROR at or near "{"
#
#
#
# ######################### CASE 45 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(49,13): ERROR at or near 'count')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (49, 13) - SyntacticError: ERROR at or near "count"
#
#
#
# ######################### CASE 46 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(51,5): ERROR at or near '}')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (51, 5) - SyntacticError: ERROR at or near "}"
#
#
#
# ######################### CASE 47 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(47,21): ERROR at or near '=>')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (47, 21) - SyntacticError: ERROR at or near DARROW
#
#
#
# ######################### CASE 48 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(49,27): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (49, 27) - SyntacticError: ERROR at or near "+"
#
#
#
# ######################### CASE 49 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(21,5): ERROR at or near 'Testing2')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (21, 5) - SyntacticError: ERROR at or near "Testing2"
#
#
#
# ######################### CASE 50 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(21,24): ERROR at or near 'B')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (21, 24) - SyntacticError: ERROR at or near "B"
#
#
#
# ######################### CASE 51 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(21,27): ERROR at or near 'int')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (21, 27) - SyntacticError: ERROR at or near "int"
#
#
#
# ######################### CASE 52 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(25,21): ERROR at or near ')')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (25, 21) - SyntacticError: ERROR at or near ")"
#
#
#
# ######################### CASE 53 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(25,17): ERROR at or near 'string')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (25, 17) - SyntacticError: ERROR at or near "string"
#
#
#
# ######################### CASE 54 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(22,5): ERROR at or near '}')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (22, 5) - SyntacticError: ERROR at or near "}"
#
#
#
# ######################### CASE 55 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(76,1): ERROR at or near 'class')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (76, 1) - SyntacticError: ERROR at or near CLASS
#
#
#
# ######################### CASE 56 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(9,7): ERROR at or near 'alpha')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (9, 7) - SyntacticError: ERROR at or near "alpha"
#
#
#
# ######################### CASE 57 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(21,18): ERROR at or near ')')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (21, 18) - SyntacticError: ERROR at or near ")"
#
#
#
# ######################### CASE 58 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(14,41): ERROR at or near 'Main')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (14, 41) - SyntacticError: ERROR at or near "Main"
#
#
#
# ######################### CASE 59 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(2,9): ERROR at or near '<-')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (2, 9) - SyntacticError: ERROR at or near ASSIGN
#
#
#
# ######################### CASE 60 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(1,1): ERROR at or near 'classs')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (1, 1) - SyntacticError: ERROR at or near "classs"
#
#
#
# ######################### CASE 61 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(74,5): ERROR at or near '}')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (74, 5) - SyntacticError: ERROR at or near "}"
#
#
#
# ######################### CASE 62 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(73,41): ERROR at or near 'int')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (73, 41) - SyntacticError: ERROR at or near "int"
#
#
#
# ######################### CASE 63 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(73,81): ERROR at or near 'Mazinger_Z')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (73, 81) - SyntacticError: ERROR at or near "Mazinger_Z"
#
#
#
# ######################### CASE 64 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(73,35): ERROR at or near '+')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (73, 35) - SyntacticError: ERROR at or near "+"
# Error de sintaxis en EOF
#
#
#
# ######################### CASE 65 #############################
# ----------------------PARSER ERRORS---------------------------
#
# ---------------------EXPECTED ERRORS:-------------------------
# (0, 0) - SyntacticError: ERROR at or near EOF
#
#
#
# ######################### CASE 66 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(16,1): ERROR at or near 'class')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (16, 1) - SyntacticError: ERROR at or near CLASS
#
#
#
# ######################### CASE 67 #############################
# ----------------------PARSER ERRORS---------------------------
# ERROR(SyntacticError(16,1): ERROR at or near 'suma')
#
# ---------------------EXPECTED ERRORS:-------------------------
# (16, 1) - SyntacticError: ERROR at or near "suma"
